# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('bank.csv')

# %%
dir(df)

# %%
df.T
# Out:
#                      0         1         2     ...      9997       9998      9999
# RowNumber               1         2         3  ...      9998       9999     10000
# CustomerId       15634602  15647311  15619304  ...  15584532   15682355  15628319
# Surname          Hargrave      Hill      Onio  ...       Liu  Sabbatini    Walker
# CreditScore           619       608       502  ...       709        772       792
# Geography          France     Spain    France  ...    France    Germany    France
# Gender             Female    Female    Female  ...    Female       Male    Female
# Age                    42        41        42  ...        36         42        28
# Tenure                  2         1         8  ...         7          3         4
# Balance                 0   83807.9    159661  ...         0    75075.3    130143
# NumOfProducts           1         1         3  ...         1          2         1
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
plt.bar(df.RowNumber,df.Age,label='Age of Customer')
plt.xlabel('Unique_Customer_ID')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
gender=df.groupby('Gender')

# %%
gender.size().plot('bar',color='orange')

# %%
df.groupby('Geography').size().plot('pie',label='Geography',shadow='true')

# %%
df.groupby('Age').size().plot('line')

# %%
plt.scatter(df.Age,df.EstimatedSalary,marker='^')
plt.scatter(df.Age,df.Balance,marker="x",color='orange')
